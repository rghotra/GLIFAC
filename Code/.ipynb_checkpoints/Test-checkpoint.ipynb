# %%
import models
import glifac_pipeline
import os

import numpy as np
import glifac, utils

# %%
file_path = '../Datasets/synthetic_interactions_dataset.h5'
file_path = os.path.abspath(file_path)

glifac_pipeline.load_dataset(file_path)

names = ['ELF1', 'SIX3', 'ESR1', 'FOXN', 'CEBPB', 'YY1', 'GATA1', 'IRF1', 'SP1', 'NFIB', 'TEAD', 'TAL1']
jaspar_ids = [utils.elf, utils.six, utils.esr, utils.foxn, utils.cebpb, utils.yy1, utils.gata, utils.irf, utils.sp1, utils.nfib, utils.tead, utils.tal]
expecteds = [['ELF1', 'SIX3'], ['ESR1', 'FOXN'], ['GATA1', 'TAL1'], ['IRF1', 'SP1']]

motifs = [jaspar_ids, names, expecteds]

# %%
model = models.CNN_ATT(
    batch_norm=False,
    activation='exp',
    pool_size=20,
    layer_norm=False
)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 4)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 200, 32)      2432        input_1[0][0]
# __________________________________________________________________________________________________
# conv_activation (Activation)    (None, 200, 32)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 10, 32)       0           conv_activation[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 32)       0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# multi_head_attention (MultiHead ((None, 10, 256), (N 90368       dropout[0][0]
#                                                                  dropout[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10, 256)      0           multi_head_attention[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2560)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          1310720     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512)          2048        dense_4[0][0]
# __________________________________________________________________________________________________
# dense_activation (Activation)   (None, 512)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_activation[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 12)           6156        dropout_2[0][0]
# ==================================================================================================
# Total params: 1,411,724
# Trainable params: 1,410,700
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %%
path = os.path.abspath('../DATA')
baseline = 'TEST'
category = 'test_cat'
variant = 'test_var'
trial = 37

# %%
glifac_pipeline.run_pipeline(
    model,
    path,
    baseline,
    category,
    variant,
    trial,
    motifs,
    batch_size=200,
    epochs=100,
    root_tomtom=False,
    concat=np.max,
    rand_frac=0.5,
    symmetrize=glifac.absmaxND
)
# Out:
# Epoch 1/100
# 350/350 - 2s - loss: 0.3505 - auroc: 0.7566 - aupr: 0.4308 - val_loss: 0.1939 - val_auroc: 0.9366 - val_aupr: 0.7765
# Epoch 2/100
# 350/350 - 2s - loss: 0.2044 - auroc: 0.9267 - aupr: 0.7651 - val_loss: 0.1395 - val_auroc: 0.9717 - val_aupr: 0.8828
# Epoch 3/100
# 350/350 - 2s - loss: 0.1708 - auroc: 0.9481 - aupr: 0.8301 - val_loss: 0.1232 - val_auroc: 0.9780 - val_aupr: 0.9057
# Epoch 4/100
# 350/350 - 2s - loss: 0.1569 - auroc: 0.9551 - aupr: 0.8539 - val_loss: 0.1165 - val_auroc: 0.9790 - val_aupr: 0.9146
# Epoch 5/100
# 350/350 - 2s - loss: 0.1501 - auroc: 0.9584 - aupr: 0.8648 - val_loss: 0.1104 - val_auroc: 0.9816 - val_aupr: 0.9224
# Epoch 6/100
# 350/350 - 2s - loss: 0.1440 - auroc: 0.9617 - aupr: 0.8737 - val_loss: 0.1090 - val_auroc: 0.9820 - val_aupr: 0.9248
# Epoch 7/100
# 350/350 - 2s - loss: 0.1409 - auroc: 0.9631 - aupr: 0.8784 - val_loss: 0.1166 - val_auroc: 0.9792 - val_aupr: 0.9183
# Epoch 8/100
# 350/350 - 2s - loss: 0.1393 - auroc: 0.9635 - aupr: 0.8811 - val_loss: 0.1120 - val_auroc: 0.9807 - val_aupr: 0.9231
# Epoch 9/100
# 350/350 - 2s - loss: 0.1378 - auroc: 0.9646 - aupr: 0.8826 - val_loss: 0.1055 - val_auroc: 0.9831 - val_aupr: 0.9272
# Epoch 10/100
# 350/350 - 2s - loss: 0.1324 - auroc: 0.9679 - aupr: 0.8905 - val_loss: 0.1047 - val_auroc: 0.9820 - val_aupr: 0.9278
# Epoch 11/100
# 350/350 - 2s - loss: 0.1279 - auroc: 0.9706 - aupr: 0.8960 - val_loss: 0.1067 - val_auroc: 0.9815 - val_aupr: 0.9245
# Epoch 12/100
# 350/350 - 2s - loss: 0.1265 - auroc: 0.9712 - aupr: 0.8980 - val_loss: 0.1101 - val_auroc: 0.9802 - val_aupr: 0.9239
# Epoch 13/100
# 350/350 - 2s - loss: 0.1223 - auroc: 0.9730 - aupr: 0.9042 - val_loss: 0.1049 - val_auroc: 0.9823 - val_aupr: 0.9276
# Epoch 14/100
# 350/350 - 2s - loss: 0.1200 - auroc: 0.9740 - aupr: 0.9069 - val_loss: 0.0996 - val_auroc: 0.9845 - val_aupr: 0.9339
# Epoch 15/100
# 350/350 - 2s - loss: 0.1182 - auroc: 0.9748 - aupr: 0.9093 - val_loss: 0.0999 - val_auroc: 0.9839 - val_aupr: 0.9327
# Epoch 16/100
# 350/350 - 2s - loss: 0.1178 - auroc: 0.9750 - aupr: 0.9098 - val_loss: 0.1009 - val_auroc: 0.9837 - val_aupr: 0.9328
# Epoch 17/100
# 350/350 - 2s - loss: 0.1170 - auroc: 0.9753 - aupr: 0.9108 - val_loss: 0.0992 - val_auroc: 0.9843 - val_aupr: 0.9330
# Epoch 18/100
# 350/350 - 2s - loss: 0.1163 - auroc: 0.9757 - aupr: 0.9119 - val_loss: 0.0992 - val_auroc: 0.9845 - val_aupr: 0.9344
# Epoch 19/100
# 350/350 - 2s - loss: 0.1162 - auroc: 0.9756 - aupr: 0.9120 - val_loss: 0.1003 - val_auroc: 0.9839 - val_aupr: 0.9331
# Epoch 20/100
# 350/350 - 2s - loss: 0.1146 - auroc: 0.9763 - aupr: 0.9139 - val_loss: 0.0982 - val_auroc: 0.9848 - val_aupr: 0.9353
# Epoch 21/100
# 350/350 - 2s - loss: 0.1150 - auroc: 0.9758 - aupr: 0.9140 - val_loss: 0.0989 - val_auroc: 0.9844 - val_aupr: 0.9349
# Epoch 22/100
# 350/350 - 2s - loss: 0.1141 - auroc: 0.9762 - aupr: 0.9148 - val_loss: 0.0970 - val_auroc: 0.9854 - val_aupr: 0.9361
# Epoch 23/100
# 350/350 - 2s - loss: 0.1127 - auroc: 0.9770 - aupr: 0.9165 - val_loss: 0.0977 - val_auroc: 0.9845 - val_aupr: 0.9347
# Epoch 24/100
# 350/350 - 2s - loss: 0.1131 - auroc: 0.9770 - aupr: 0.9160 - val_loss: 0.0972 - val_auroc: 0.9845 - val_aupr: 0.9364
# Epoch 25/100
# 350/350 - 2s - loss: 0.1128 - auroc: 0.9770 - aupr: 0.9163 - val_loss: 0.0990 - val_auroc: 0.9842 - val_aupr: 0.9349
# Epoch 26/100
# 350/350 - 2s - loss: 0.1126 - auroc: 0.9771 - aupr: 0.9164 - val_loss: 0.1001 - val_auroc: 0.9838 - val_aupr: 0.9333
# Epoch 27/100
# 350/350 - 2s - loss: 0.1119 - auroc: 0.9774 - aupr: 0.9177 - val_loss: 0.0991 - val_auroc: 0.9838 - val_aupr: 0.9350
# Epoch 28/100
# 350/350 - 2s - loss: 0.1122 - auroc: 0.9772 - aupr: 0.9174 - val_loss: 0.0996 - val_auroc: 0.9836 - val_aupr: 0.9335
# Epoch 29/100
# 350/350 - 2s - loss: 0.1115 - auroc: 0.9776 - aupr: 0.9183 - val_loss: 0.0980 - val_auroc: 0.9844 - val_aupr: 0.9352
# Epoch 30/100
# 350/350 - 2s - loss: 0.1113 - auroc: 0.9775 - aupr: 0.9187 - val_loss: 0.0999 - val_auroc: 0.9832 - val_aupr: 0.9329
# Epoch 31/100
# 350/350 - 2s - loss: 0.1105 - auroc: 0.9779 - aupr: 0.9197 - val_loss: 0.0953 - val_auroc: 0.9854 - val_aupr: 0.9370
# Epoch 32/100
# 350/350 - 2s - loss: 0.1109 - auroc: 0.9777 - aupr: 0.9197 - val_loss: 0.0971 - val_auroc: 0.9845 - val_aupr: 0.9367
# Epoch 33/100
# 350/350 - 2s - loss: 0.1091 - auroc: 0.9787 - aupr: 0.9225 - val_loss: 0.0959 - val_auroc: 0.9857 - val_aupr: 0.9423
# Epoch 34/100
# 350/350 - 2s - loss: 0.1057 - auroc: 0.9799 - aupr: 0.9273 - val_loss: 0.0859 - val_auroc: 0.9884 - val_aupr: 0.9496
# Epoch 35/100
# 350/350 - 2s - loss: 0.1026 - auroc: 0.9803 - aupr: 0.9306 - val_loss: 0.0821 - val_auroc: 0.9886 - val_aupr: 0.9532
# Epoch 36/100
# 350/350 - 2s - loss: 0.0970 - auroc: 0.9814 - aupr: 0.9363 - val_loss: 0.0769 - val_auroc: 0.9909 - val_aupr: 0.9589
# Epoch 37/100
# 350/350 - 2s - loss: 0.0941 - auroc: 0.9823 - aupr: 0.9398 - val_loss: 0.0778 - val_auroc: 0.9900 - val_aupr: 0.9596
# Epoch 38/100
# 350/350 - 2s - loss: 0.0920 - auroc: 0.9832 - aupr: 0.9418 - val_loss: 0.0752 - val_auroc: 0.9907 - val_aupr: 0.9606
# Epoch 39/100
# 350/350 - 2s - loss: 0.0923 - auroc: 0.9828 - aupr: 0.9412 - val_loss: 0.0765 - val_auroc: 0.9903 - val_aupr: 0.9615
# Epoch 40/100
# 350/350 - 2s - loss: 0.0911 - auroc: 0.9833 - aupr: 0.9426 - val_loss: 0.0742 - val_auroc: 0.9912 - val_aupr: 0.9624
# Epoch 41/100
# 350/350 - 2s - loss: 0.0906 - auroc: 0.9834 - aupr: 0.9433 - val_loss: 0.0758 - val_auroc: 0.9907 - val_aupr: 0.9613
# Epoch 42/100
# 350/350 - 2s - loss: 0.0902 - auroc: 0.9835 - aupr: 0.9438 - val_loss: 0.0756 - val_auroc: 0.9908 - val_aupr: 0.9619
# Epoch 43/100
# 350/350 - 2s - loss: 0.0897 - auroc: 0.9838 - aupr: 0.9442 - val_loss: 0.0732 - val_auroc: 0.9914 - val_aupr: 0.9629
# Epoch 44/100
# 350/350 - 2s - loss: 0.0898 - auroc: 0.9837 - aupr: 0.9440 - val_loss: 0.0743 - val_auroc: 0.9909 - val_aupr: 0.9622
# Epoch 45/100
# 350/350 - 2s - loss: 0.0892 - auroc: 0.9841 - aupr: 0.9446 - val_loss: 0.0757 - val_auroc: 0.9908 - val_aupr: 0.9619
# Epoch 46/100
# 350/350 - 2s - loss: 0.0888 - auroc: 0.9840 - aupr: 0.9454 - val_loss: 0.0733 - val_auroc: 0.9911 - val_aupr: 0.9621
# Epoch 47/100
# 350/350 - 2s - loss: 0.0886 - auroc: 0.9840 - aupr: 0.9454 - val_loss: 0.0756 - val_auroc: 0.9903 - val_aupr: 0.9598
# Epoch 48/100
# 350/350 - 2s - loss: 0.0884 - auroc: 0.9844 - aupr: 0.9457 - val_loss: 0.0751 - val_auroc: 0.9905 - val_aupr: 0.9610
# Epoch 49/100
# 350/350 - 2s - loss: 0.0879 - auroc: 0.9845 - aupr: 0.9461 - val_loss: 0.0755 - val_auroc: 0.9906 - val_aupr: 0.9620
# Epoch 50/100
# 350/350 - 2s - loss: 0.0875 - auroc: 0.9844 - aupr: 0.9468 - val_loss: 0.0735 - val_auroc: 0.9914 - val_aupr: 0.9621
# Epoch 51/100
# 350/350 - 2s - loss: 0.0875 - auroc: 0.9845 - aupr: 0.9467 - val_loss: 0.0754 - val_auroc: 0.9905 - val_aupr: 0.9617
# Epoch 52/100
# 350/350 - 2s - loss: 0.0873 - auroc: 0.9846 - aupr: 0.9468 - val_loss: 0.0750 - val_auroc: 0.9903 - val_aupr: 0.9611
# Epoch 53/100
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 350/350 - 2s - loss: 0.0871 - auroc: 0.9846 - aupr: 0.9473 - val_loss: 0.0734 - val_auroc: 0.9909 - val_aupr: 0.9622
# Epoch 54/100
# 350/350 - 2s - loss: 0.0848 - auroc: 0.9852 - aupr: 0.9497 - val_loss: 0.0724 - val_auroc: 0.9911 - val_aupr: 0.9635
# Epoch 55/100
# 350/350 - 2s - loss: 0.0839 - auroc: 0.9856 - aupr: 0.9507 - val_loss: 0.0732 - val_auroc: 0.9908 - val_aupr: 0.9631
# Epoch 56/100
# 350/350 - 2s - loss: 0.0833 - auroc: 0.9860 - aupr: 0.9511 - val_loss: 0.0729 - val_auroc: 0.9911 - val_aupr: 0.9634
# Epoch 57/100
# 350/350 - 2s - loss: 0.0830 - auroc: 0.9858 - aupr: 0.9514 - val_loss: 0.0730 - val_auroc: 0.9907 - val_aupr: 0.9630
# Epoch 58/100
# 350/350 - 2s - loss: 0.0826 - auroc: 0.9858 - aupr: 0.9518 - val_loss: 0.0725 - val_auroc: 0.9911 - val_aupr: 0.9633
# Epoch 59/100
# 350/350 - 2s - loss: 0.0821 - auroc: 0.9862 - aupr: 0.9522 - val_loss: 0.0721 - val_auroc: 0.9913 - val_aupr: 0.9634
# Epoch 60/100
# 350/350 - 2s - loss: 0.0820 - auroc: 0.9860 - aupr: 0.9525 - val_loss: 0.0725 - val_auroc: 0.9909 - val_aupr: 0.9633
# Epoch 61/100
# 350/350 - 2s - loss: 0.0817 - auroc: 0.9864 - aupr: 0.9525 - val_loss: 0.0718 - val_auroc: 0.9913 - val_aupr: 0.9636
# Epoch 62/100
# 350/350 - 2s - loss: 0.0819 - auroc: 0.9861 - aupr: 0.9524 - val_loss: 0.0725 - val_auroc: 0.9910 - val_aupr: 0.9632
# Epoch 63/100
# 350/350 - 2s - loss: 0.0824 - auroc: 0.9858 - aupr: 0.9519 - val_loss: 0.0722 - val_auroc: 0.9911 - val_aupr: 0.9632
# Epoch 64/100
# 350/350 - 2s - loss: 0.0818 - auroc: 0.9860 - aupr: 0.9526 - val_loss: 0.0735 - val_auroc: 0.9905 - val_aupr: 0.9628
# Epoch 65/100
# 350/350 - 2s - loss: 0.0817 - auroc: 0.9862 - aupr: 0.9529 - val_loss: 0.0730 - val_auroc: 0.9909 - val_aupr: 0.9633
# Epoch 66/100
# 350/350 - 2s - loss: 0.0815 - auroc: 0.9861 - aupr: 0.9530 - val_loss: 0.0728 - val_auroc: 0.9907 - val_aupr: 0.9629
# Epoch 67/100
# 350/350 - 2s - loss: 0.0817 - auroc: 0.9861 - aupr: 0.9529 - val_loss: 0.0720 - val_auroc: 0.9912 - val_aupr: 0.9634
# Epoch 68/100
# 350/350 - 2s - loss: 0.0814 - auroc: 0.9863 - aupr: 0.9530 - val_loss: 0.0722 - val_auroc: 0.9911 - val_aupr: 0.9634
# Epoch 69/100
# 350/350 - 2s - loss: 0.0802 - auroc: 0.9867 - aupr: 0.9543 - val_loss: 0.0726 - val_auroc: 0.9906 - val_aupr: 0.9631
# Epoch 70/100
# 350/350 - 2s - loss: 0.0807 - auroc: 0.9866 - aupr: 0.9539 - val_loss: 0.0725 - val_auroc: 0.9909 - val_aupr: 0.9628
# Epoch 71/100
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 350/350 - 2s - loss: 0.0807 - auroc: 0.9863 - aupr: 0.9534 - val_loss: 0.0733 - val_auroc: 0.9906 - val_aupr: 0.9626
# Epoch 72/100
# 350/350 - 2s - loss: 0.0804 - auroc: 0.9865 - aupr: 0.9541 - val_loss: 0.0729 - val_auroc: 0.9907 - val_aupr: 0.9630
# Epoch 73/100
# 350/350 - 2s - loss: 0.0807 - auroc: 0.9862 - aupr: 0.9539 - val_loss: 0.0727 - val_auroc: 0.9907 - val_aupr: 0.9630
# Epoch 74/100
# 350/350 - 2s - loss: 0.0805 - auroc: 0.9863 - aupr: 0.9539 - val_loss: 0.0725 - val_auroc: 0.9908 - val_aupr: 0.9631
# Epoch 75/100
# 350/350 - 2s - loss: 0.0800 - auroc: 0.9868 - aupr: 0.9544 - val_loss: 0.0725 - val_auroc: 0.9908 - val_aupr: 0.9630
# Epoch 76/100
# Restoring model weights from the end of the best epoch.
# 350/350 - 2s - loss: 0.0805 - auroc: 0.9865 - aupr: 0.9538 - val_loss: 0.0727 - val_auroc: 0.9908 - val_aupr: 0.9631
# Epoch 00076: early stopping
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0718 - auroc: 0.9913 - aupr: 0.9635
# generated PPMs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-283a94251888> in <module>
# ----> 1 glifac_pipeline.run_pipeline(
#       2     model,
#       3     path,
#       4     baseline,
#       5     category,
#
# ~/Documents/GLIFAC/Code/glifac_pipeline.py in run_pipeline(model, path, baseline, category, variant, trial, motifs, batch_size, epochs, root_tomtom, concat, rand_frac, symmetrize)
#     183     names = ['ELF1', 'SIX3', 'ESR1', 'FOXN', 'CEBPB', 'YY1', 'GATA1', 'IRF1', 'SP1', 'NFIB', 'TEAD', 'TAL1']
#     184
# --> 185     match_fraction, match_any, filter_match, filter_qvalue, min_qvalue, num_counts, coverage = utils.get_tomtom_stats(tomtom_dir + '/tomtom.tsv', 32)
#     186     filter_matches = np.array(filter_match)
#     187     tomtom_tpr = match_fraction
#
# ~/Documents/GLIFAC/Code/utils.py in get_tomtom_stats(tomtom_dir, num_filters)
#      84 def get_tomtom_stats(tomtom_dir, num_filters=32):
#      85
# ---> 86     match_fraction, match_any, filter_match, filter_qvalue, min_qvalue, num_counts = moana.match_hits_to_ground_truth(tomtom_dir, motifs, motif_names, num_filters)
#      87
#      88     qvalues, coverage = get_qvalues(filter_match, filter_qvalue, motif_names)
#
# ~/tf_2/lib/python3.8/site-packages/tfomics/moana.py in match_hits_to_ground_truth(file_path, motifs, motif_names, num_filters)
#     158
#     159   # get dataframe for tomtom results
# --> 160   df = pd.read_csv(file_path, delimiter='\t')
#     161
#     162   # loop through filters
#
# ~/tf_2/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/tf_2/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/tf_2/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/tf_2/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/tf_2/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/tf_2/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/tf_2/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/koolab/Documents/GLIFAC/DATA/TEST/tomtom/test_cat/model-test_var/trial-37/tomtom.tsv'

# %%
print(path)

print(path[:path.index('GLIFAC')] + 'GLIFAC/Datasets/motif_database.txt')
# Out:
# /home/koolab/Documents/GLIFAC/DATA
# /home/koolab/Documents/
